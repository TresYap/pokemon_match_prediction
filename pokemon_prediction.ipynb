# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
train = pd.read_csv("battles_updated.csv")
test = pd.read_csv("tests.csv")
pokemon = pd.read_csv("pokemon.csv")
typechart = pd.read_csv("chart.csv")

# %%
train
# Out:
#       second_Type 1 second_Type 2  second_HP  second_Attack  second_Defense  \
# 0             Grass        Poison         45             24              49
# 1             Grass        Poison         45             49              49
# 2             Grass        Poison         45             12              49
# 3             Grass        Poison         45             24              49
# 4             Grass        Poison         45             12              49
# ...             ...           ...        ...            ...             ...
# 49995          Fire         Water         80            220             120
# 49996          Fire         Water         80             27             120
# 49997          Fire         Water         80             27             120
# 49998          Fire         Water         80             27             120
# 49999          Fire         Water         80            110             120
#
#        second_Sp. Atk  second_Sp. Def  second_Speed first_Type 1 first_Type 2  \
# 0                  32              65            45       Normal       Flying
# 1                  65              65            45       Normal      No Type
# 2                  16              65            45        Grass       Poison
# 3                  32              65            45         Fire      No Type
# 4                  16              65            45        Grass       Poison
# ...               ...             ...           ...          ...          ...
# 49995             260              90            70          Bug       Flying
# 49996              32              90            70       Poison        Water
# 49997              32              90            70       Poison        Water
# 49998              32              90            70       Dragon      No Type
# 49999             130              90            70        Ghost        Grass
#
#        first_HP  first_Attack  first_Defense  first_Sp. Atk  first_Sp. Def  \
# 0            40            90             40             70             35
# 1            30            56             35             25             35
# 2            60            16             70             21             75
# 3            55           140             45            140             50
# 4            50            18             35             17             30
# ...         ...           ...            ...            ...            ...
# 49995        80            26             50             45             50
# 49996        50            60             60             60             60
# 49997        50            60             60             60             60
# 49998        68            75             53             83            113
# 49999        59            66             70             44             55
#
#        first_Speed  First_pokemon  Second_pokemon  outcome
# 0               56             21               1        0
# 1               72             25               1        0
# 2               40             50               1        1
# 3               60             64               1        0
# 4               40             76               1        1
# ...            ...            ...             ...      ...
# 49995           89            735             800        0
# 49996           30            761             800        1
# 49997           30            761             800        1
# 49998           60            776             800        1
# 49999           41            784             800        1
#
# [50000 rows x 19 columns]

# %% [markdown]
# Baseline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
train.head(1)
# Out:
#   second_Type 1 second_Type 2  second_HP  second_Attack  second_Defense  \
# 0         Grass        Poison         45             24              49
#
#    second_Sp. Atk  second_Sp. Def  second_Speed first_Type 1 first_Type 2  \
# 0              32              65            45       Normal       Flying
#
#    first_HP  first_Attack  first_Defense  first_Sp. Atk  first_Sp. Def  \
# 0        40            90             40             70             35
#
#    first_Speed  First_pokemon  Second_pokemon  outcome
# 0           56             21               1        0

# %%
#Drop unnecessary columns
try:
    drop = ["first_Type 1", "first_Type 2", "second_Type 1", "second_Type 2", "First_pokemon", "Second_pokemon"]
    train.drop(drop, axis=1, inplace=True)
except Exception as e:
    print(e)

# %%
train
# Out:
#        second_HP  second_Attack  second_Defense  second_Sp. Atk  \
# 0             45             24              49              32
# 1             45             49              49              65
# 2             45             12              49              16
# 3             45             24              49              32
# 4             45             12              49              16
# ...          ...            ...             ...             ...
# 49995         80            220             120             260
# 49996         80             27             120              32
# 49997         80             27             120              32
# 49998         80             27             120              32
# 49999         80            110             120             130
#
#        second_Sp. Def  second_Speed  first_HP  first_Attack  first_Defense  \
# 0                  65            45        40            90             40
# 1                  65            45        30            56             35
# 2                  65            45        60            16             70
# 3                  65            45        55           140             45
# 4                  65            45        50            18             35
# ...               ...           ...       ...           ...            ...
# 49995              90            70        80            26             50
# 49996              90            70        50            60             60
# 49997              90            70        50            60             60
# 49998              90            70        68            75             53
# 49999              90            70        59            66             70
#
#        first_Sp. Atk  first_Sp. Def  first_Speed  outcome
# 0                 70             35           56        0
# 1                 25             35           72        0
# 2                 21             75           40        1
# 3                140             50           60        0
# 4                 17             30           40        1
# ...              ...            ...          ...      ...
# 49995             45             50           89        0
# 49996             60             60           30        1
# 49997             60             60           30        1
# 49998             83            113           60        1
# 49999             44             55           41        1
#
# [50000 rows x 13 columns]

# %%
y = train.outcome
train.drop("outcome", axis=1, inplace=True)

# %%
reg_model = LogisticRegression()
svm_model = LinearSVC(max_iter=10000)
rf_model = RandomForestClassifier(n_estimators=300)
reg_scores = cross_val_score(reg_model, train, y, cv=5, scoring="f1")
svm_scores = cross_val_score(svm_model, train, y, cv=5, scoring="f1")
rf_scores = cross_val_score(rf_model, train, y, cv=5, scoring="f1")
# Out:
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\tresyap\Anaconda3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
print("Cross-Validation F1 Scores (mean):")
print("Logistic Regression: %0.2f" % reg_scores.mean())
print("SVM: %0.2f" % svm_scores.mean())
print("Random Forest: %0.2f" % rf_scores.mean())
# Out:
# Cross-Validation F1 Scores (mean):
# Logistic Regression: 0.90
# SVM: 0.79
# Random Forest: 0.95
